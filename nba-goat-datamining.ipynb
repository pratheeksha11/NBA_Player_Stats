# %% [markdown]
# <a href="https://www.kaggle.com/code/pratheekshanath/nba-goat-datamining?scriptVersionId=159798695" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nba-players-data/all_seasons.csv

# %%
df = pd.read_csv('/kaggle/input/nba-players-data/all_seasons.csv')
df
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
import pandasql as psql

# %%
query = "SELECT * FROM df WHERE player_name = 'LeBron James'"

lebron_james = psql.sqldf(query, locals())

lebron_james
# Out:
#     Unnamed: 0   player_name team_abbreviation   age  player_height  \
# 0         3448  LeBron James               CLE  19.0         203.20
# 1         3616  LeBron James               CLE  20.0         203.20
# 2         4103  LeBron James               CLE  21.0         203.20
# 3         4807  LeBron James               CLE  22.0         203.20
# 4         5133  LeBron James               CLE  23.0         203.20
# 5         5387  LeBron James               CLE  24.0         203.20
# 6         6099  LeBron James               CLE  25.0         203.20
# 7         6585  LeBron James               MIA  26.0         203.20
# 8         6746  LeBron James               MIA  27.0         203.20
# 9         7585  LeBron James               MIA  28.0         203.20
# 10        7977  LeBron James               MIA  29.0         203.20
# 11        8190  LeBron James               CLE  30.0         203.20
# 12        8979  LeBron James               CLE  31.0         203.20
# ...

# %%
lebron_james.to_csv('/kaggle/working/lebron_james.csv', index=False)
print('file saved')
# Out:
# file saved

# %%
query = "SELECT * FROM df WHERE player_name = 'Kobe Bryant'"

kobe_bryant = psql.sqldf(query, locals())

kobe_bryant
# Out:
#     Unnamed: 0  player_name team_abbreviation   age  player_height  \
# 0          334  Kobe Bryant               LAL  18.0         200.66
# 1          496  Kobe Bryant               LAL  19.0         200.66
# 2         1225  Kobe Bryant               LAL  20.0         200.66
# 3         1413  Kobe Bryant               LAL  21.0         200.66
# 4         1882  Kobe Bryant               LAL  22.0         200.66
# 5         2445  Kobe Bryant               LAL  23.0         200.66
# 6         2718  Kobe Bryant               LAL  24.0         200.66
# 7         3440  Kobe Bryant               LAL  25.0         198.12
# 8         3569  Kobe Bryant               LAL  26.0         198.12
# 9         4163  Kobe Bryant               LAL  27.0         198.12
# 10        4817  Kobe Bryant               LAL  28.0         198.12
# 11        5201  Kobe Bryant               LAL  29.0         198.12
# 12        5420  Kobe Bryant               LAL  30.0         198.12
# ...

# %%
kobe_bryant.to_csv('/kaggle/working/kobe_bryant.csv', index=False)
print('file saved')
# Out:
# file saved
